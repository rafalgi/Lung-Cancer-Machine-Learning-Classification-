# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('cancer patient data sets.csv')
df
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %%
df.columns
# Out:
# Index(['index', 'Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     1000 non-null   int64
#  1   Patient Id                1000 non-null   object
#  2   Age                       1000 non-null   int64
#  3   Gender                    1000 non-null   int64
#  4   Air Pollution             1000 non-null   int64
#  5   Alcohol use               1000 non-null   int64
#  6   Dust Allergy              1000 non-null   int64
#  7   OccuPational Hazards      1000 non-null   int64
#  8   Genetic Risk              1000 non-null   int64
#  9   chronic Lung Disease      1000 non-null   int64
#  10  Balanced Diet             1000 non-null   int64
#  11  Obesity                   1000 non-null   int64
#  12  Smoking                   1000 non-null   int64
#  13  Passive Smoker            1000 non-null   int64
# ...

# %%
df.drop('Patient Id', axis = 1)
# Out:
#      index  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0   33       1              2            4             5
# 1        1   17       1              3            1             5
# 2        2   35       1              4            5             6
# 3        3   37       1              7            7             7
# 4        4   46       1              6            8             7
# ..     ...  ...     ...            ...          ...           ...
# 995    995   44       1              6            7             7
# 996    996   37       2              6            8             7
# 997    997   25       2              4            5             6
# 998    998   18       2              6            8             7
# 999    999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# ...

# %%
df = df.replace({'Level': {'Low': 1, 'Medium': 2, 'High': 3}})

# %%
df = df.drop('Patient Id', axis=1)

# %%
scaler = MinMaxScaler()
scaler.fit(df)
df_scaled=pd.DataFrame(scaler.transform(df), columns=df.columns)
df_scaled
# Out:
#         index       Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0    0.000000  0.322034     0.0       0.142857     0.428571      0.571429
# 1    0.001001  0.050847     0.0       0.285714     0.000000      0.571429
# 2    0.002002  0.355932     0.0       0.428571     0.571429      0.714286
# 3    0.003003  0.389831     0.0       0.857143     0.857143      0.857143
# 4    0.004004  0.542373     0.0       0.714286     1.000000      0.857143
# ..        ...       ...     ...            ...          ...           ...
# 995  0.995996  0.508475     0.0       0.714286     0.857143      0.857143
# 996  0.996997  0.389831     1.0       0.714286     1.000000      0.857143
# 997  0.997998  0.186441     1.0       0.428571     0.571429      0.714286
# 998  0.998999  0.067797     1.0       0.714286     1.000000      0.857143
# 999  1.000000  0.559322     0.0       0.714286     0.571429      0.714286
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
y = df.pop('Level')
x = df
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2 , shuffle= True)

# %%
for i in range(2,10):
    pca = PCA(n_components=i)
    pca.fit(x_train)
    print(f"Redukcja z 10 do {i} dokladnoscL: {sum(pca.explained_variance_ratio_ * 100.0):.1f}%.")
    print("Znaczenie kolejnych cech \n " + "\n".join(str(i) for i in pca.explained_variance_ratio_))
# Out:
# Redukcja z 10 do 2 dokladnoscL: 99.9%.
# Znaczenie kolejnych cech
#  0.997062944516556
# 0.0017521417768058317
# Redukcja z 10 do 3 dokladnoscL: 99.9%.
# Znaczenie kolejnych cech
#  0.997062944516556
# 0.0017521417768058339
# 0.0005194312672140998
# Redukcja z 10 do 4 dokladnoscL: 99.9%.
# Znaczenie kolejnych cech
#  0.997062944516556
# 0.0017521417768058326
# 0.0005194312672140947
# 0.00016503082100647622
# Redukcja z 10 do 5 dokladnoscL: 100.0%.
# Znaczenie kolejnych cech
#  0.997062944516556
# 0.001752141776805831
# 0.0005194312672141011
# 0.00016503082100909853
# 0.00010844652424523175
# Redukcja z 10 do 6 dokladnoscL: 100.0%.
# Znaczenie kolejnych cech
#  0.997062944516556
# 0.0017521417768058308
# 0.000519431267214103
# 0.0001650308210067222
# 0.0001084465242522261
# 8.165778757407911e-05
# Redukcja z 10 do 7 dokladnoscL: 100.0%.
# Znaczenie kolejnych cech
#  0.9970629445165554
# 0.0017521417768058339
# 0.000519431267214103
# 0.00016503082100931095
# 0.00010844652427191066
# ...

# %%
for i in range(2,10):
    n = KNeighborsClassifier(8)
    n.fit(x_train, y_train)
    score = n.score(x_test,y_test)
    print(f"Dla k {i} score : {score}")
# Out:
# Dla k 2 score : 0.745
# Dla k 3 score : 0.745
# Dla k 4 score : 0.745
# Dla k 5 score : 0.745
# Dla k 6 score : 0.745
# Dla k 7 score : 0.745
# Dla k 8 score : 0.745
# Dla k 9 score : 0.745

# %%
rf = RandomForestClassifier(max_depth=20, random_state=200)
rf.fit(x_train, y_train)
rf.score(x_test , y_test)
# Out:
# 1.0

# %%
lr = LinearRegression().fit(x_train, y_train)
lr.score(x_test , y_test)
# Out:
# 0.9310407217622438

# %%
def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array[i], true_label[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1]) 
  predicted_label = np.argmax(predictions_array)
  
  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
crf.predict(x_test)
# Out:
# array([1, 1, 1, 2, 2, 3, 2, 2, 2, 3, 1, 1, 3, 3, 1, 2, 2, 3, 3, 3, 2, 3,
#        1, 3, 2, 3, 1, 1, 3, 3, 3, 2, 3, 3, 2, 3, 3, 2, 3, 2, 3, 2, 1, 1,
#        2, 3, 3, 3, 1, 1, 2, 2, 1, 1, 3, 3, 1, 2, 3, 3, 3, 3, 3, 1, 1, 3,
#        3, 2, 2, 1, 1, 1, 2, 1, 3, 1, 2, 3, 2, 2, 1, 3, 3, 3, 3, 1, 2, 3,
#        3, 2, 1, 2, 3, 1, 2, 2, 2, 3, 1, 1, 2, 3, 3, 3, 3, 3, 3, 2, 3, 2,
#        1, 2, 2, 3, 1, 3, 3, 3, 3, 2, 1, 3, 2, 1, 2, 3, 2, 2, 1, 2, 1, 1,
#        2, 1, 2, 2, 1, 3, 1, 1, 3, 1, 3, 3, 3, 3, 1, 2, 3, 1, 3, 1, 3, 3,
#        3, 1, 1, 2, 3, 3, 3, 1, 2, 1, 1, 1, 1, 2, 1, 3, 1, 3, 1, 1, 2, 3,
#        3, 2, 3, 3, 2, 2, 3, 1, 3, 2, 3, 3, 3, 3, 3, 2, 3, 1, 1, 1, 2, 2,
#        1, 3], dtype=int64)

# %%
y_test
# Out:
# 153    1
# 726    1
# 236    1
# 411    2
# 15     2
#       ..
# 596    1
# 415    2
# 786    2
# 940    1
# 762    3
# Name: Level, Length: 200, dtype: int64

# %%
i = 1
predictions = n.predict(x_test)
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plt.subplot(1,2,2)
plot_value_array(i, predictions, y_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 6
#       4 plt.subplot(1,2,1)
#       5 plt.subplot(1,2,2)
# ...
